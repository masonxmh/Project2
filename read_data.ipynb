# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
data = pd.read_csv("data/dxy/20200125-225300-dxy-2019ncov-data.csv",delimiter=("|"),skiprows=2)

# %%
data.head()
# Out:
#      # place  confirmed_cases  deaths notes  sources
# 0      Hubei              730      39   NaN      NaN
# 1  Guangdong               78       0   NaN      NaN
# 2   Zhejiang               62       0   NaN      NaN
# 3  Chongqing               57       0   NaN      NaN
# 4      Hunan               43       0   NaN      NaN

# %%
data["date"] = "20200125"

# %%
data
# Out:
#            # place  confirmed_cases  deaths          notes  sources      date
# 0            Hubei              730      39            NaN      NaN  20200125
# 1        Guangdong               78       0            NaN      NaN  20200125
# 2         Zhejiang               62       0            NaN      NaN  20200125
# 3        Chongqing               57       0            NaN      NaN  20200125
# 4            Hunan               43       0            NaN      NaN  20200125
# 5          Beijing               41       0            NaN      NaN  20200125
# 6            Anhui               39       0            NaN      NaN  20200125
# 7         Shanghai               33       0            NaN      NaN  20200125
# 8            Henan               32       0            NaN      NaN  20200125
# 9          Sichuan               28       0            NaN      NaN  20200125
# 10        Shandong               27       0            NaN      NaN  20200125
# ...

# %%
data=data.drop(["sources"],axis=1)

# %%
engine = create_engine('sqlite:///my_lite_store.db')
data.to_sql('China', engine, index=False,if_exists='replace')

# %%
df = pd.read_sql_query('SELECT * FROM China',engine)
df.head()
# Out:
#      # place  confirmed_cases  deaths      date
# 0      Hubei              730      39  20200125
# 1  Guangdong               78       0  20200125
# 2   Zhejiang               62       0  20200125
# 3  Chongqing               57       0  20200125
# 4      Hunan               43       0  20200125

# %%
data2 = pd.read_csv("data/dxy/20200126-125300-dxy-2019ncov-data.csv",delimiter=("|"),skiprows=2)

# %%
data2
# Out:
#            # place                                    confirmed_cases  \
# 0            Hubei                                               1052
# 1         Zhejiang                                                104
# 2        Guangdong                                                 98
# 3            Henan                                                 83
# 4        Chongqing                                                 75
# 5            Hunan                                                 69
# 6            Anhui                                                 60
# 7          Beijing                                                 54
# 8          Sichuan                                                 44
# 9         Shanghai                                                 40
# 10        Shandong                                                 39
# 11         Jiangxi                                                 36
# ...

# %%
data3 = pd.read_csv("data/dxy/20200126-125300-dxy-2019ncov-data.csv",delimiter=("|"),skiprows=2)
